# %%
import pandas as pd

# %%
income = pd.read_csv("income.csv")

# %%
income.columns
# Out:
# Index(['Index', 'State', 'Y2002', 'Y2003', 'Y2004', 'Y2005', 'Y2006', 'Y2007',
#        'Y2008', 'Y2009', 'Y2010', 'Y2011', 'Y2012', 'Y2013', 'Y2014', 'Y2015'],
#       dtype='object')

# %%
income.columns[0:4]
# Out:
# Index(['Index', 'State', 'Y2002', 'Y2003'], dtype='object')

# %%
income.dtypes
# Out:
# Index    object
# State    object
# Y2002     int64
# Y2003     int64
# Y2004     int64
# Y2005     int64
# Y2006     int64
# Y2007     int64
# Y2008     int64
# Y2009     int64
# Y2010     int64
# Y2011     int64
# Y2012     int64
# Y2013     int64
# Y2014     int64
# Y2015     int64
# dtype: object

# %%
income['Y2015'].dtypes
# Out:
# dtype('int64')

# %%
income.Y2002 = income.Y2002.astype(float)

# %%
income.dtypes
# Out:
# Index     object
# State     object
# Y2002    float64
# Y2003      int64
# Y2004      int64
# Y2005      int64
# Y2006      int64
# Y2007      int64
# Y2008      int64
# Y2009      int64
# Y2010      int64
# Y2011      int64
# Y2012      int64
# Y2013      int64
# Y2014      int64
# Y2015      int64
# dtype: object

# %%
income.Y2002 = income.Y2002.astype(int)

# %%
income.dtypes
# Out:
# Index    object
# State    object
# Y2002     int32
# Y2003     int64
# Y2004     int64
# Y2005     int64
# Y2006     int64
# Y2007     int64
# Y2008     int64
# Y2009     int64
# Y2010     int64
# Y2011     int64
# Y2012     int64
# Y2013     int64
# Y2014     int64
# Y2015     int64
# dtype: object

# %%
income.shape
# Out:
# (51, 16)

# %%
income.shape[0]
# Out:
# 51

# %%
income.shape[1]
# Out:
# 16

# %%
income.head(5)
# Out:
#   Index       State    Y2002    Y2003    Y2004    Y2005    Y2006    Y2007  \
# 0     A     Alabama  1296530  1317711  1118631  1492583  1107408  1440134
# 1     A      Alaska  1170302  1960378  1818085  1447852  1861639  1465841
# 2     A     Arizona  1742027  1968140  1377583  1782199  1102568  1109382
# 3     A    Arkansas  1485531  1994927  1119299  1947979  1669191  1801213
# 4     C  California  1685349  1675807  1889570  1480280  1735069  1812546
#
#      Y2008    Y2009    Y2010    Y2011    Y2012    Y2013    Y2014    Y2015
# 0  1945229  1944173  1237582  1440756  1186741  1852841  1558906  1916661
# 1  1551826  1436541  1629616  1230866  1512804  1985302  1580394  1979143
# 2  1752886  1554330  1300521  1130709  1907284  1363279  1525866  1647724
# 3  1188104  1628980  1669295  1928238  1216675  1591896  1360959  1329341
# 4  1487315  1663809  1624509  1639670  1921845  1156536  1388461  1644607

# %%
income.tail(2)
# Out:
#    Index      State    Y2002    Y2003    Y2004    Y2005    Y2006    Y2007  \
# 49     W  Wisconsin  1788920  1518578  1289663  1436888  1251678  1721874
# 50     W    Wyoming  1775190  1498098  1198212  1881688  1750527  1523124
#
#       Y2008    Y2009    Y2010    Y2011    Y2012    Y2013    Y2014    Y2015
# 49  1980167  1901394  1648755  1940943  1729177  1510119  1701650  1846238
# 50  1587602  1504455  1282142  1881814  1673668  1994022  1204029  1853858

# %%
income.iloc[5:10]
# Out:
#   Index                 State    Y2002    Y2003    Y2004    Y2005    Y2006  \
# 5     C              Colorado  1343824  1878473  1886149  1236697  1871471
# 6     C           Connecticut  1610512  1232844  1181949  1518933  1841266
# 7     D              Delaware  1330403  1268673  1706751  1403759  1441351
# 8     D  District of Columbia  1111437  1993741  1374643  1827949  1803852
# 9     F               Florida  1964626  1468852  1419738  1362787  1339608
#
#      Y2007    Y2008    Y2009    Y2010    Y2011    Y2012    Y2013    Y2014  \
# 5  1814218  1875146  1752387  1913275  1665877  1491604  1178355  1383978
# 6  1976976  1764457  1972730  1968730  1945524  1228529  1582249  1503156
# 7  1300836  1762096  1553585  1370984  1318669  1984027  1671279  1803169
# 8  1595981  1193245  1739748  1707823  1353449  1979708  1912654  1782169
# 9  1278550  1756185  1818438  1198403  1497051  1131928  1107448  1407784
#
#      Y2015
# 5  1330736
# 6  1718072
# 7  1627508
# 8  1410183
# ...

# %%
income.Index.unique()
# Out:
# array(['A', 'C', 'D', 'F', 'G', 'H', 'I', 'K', 'L', 'M', 'N', 'O', 'P',
#        'R', 'S', 'T', 'U', 'V', 'W'], dtype=object)

# %%
income.Index.nunique()
# Out:
# 19

# %%
income.Index.value_counts(ascending=True)
# Out:
# H    1
# F    1
# U    1
# L    1
# P    1
# R    1
# G    1
# S    2
# V    2
# K    2
# D    2
# T    2
# C    3
# O    3
# A    4
# W    4
# I    4
# M    8
# N    8
# Name: Index, dtype: int64

# %%
income.sample(5)
# Out:
#    Index          State    Y2002    Y2003    Y2004    Y2005    Y2006    Y2007  \
# 21     M  Massachusetts  1647582  1686259  1620601  1777250  1531641  1380529
# 16     K         Kansas  1509054  1290700  1522230  1532094  1104256  1863278
# 6      C    Connecticut  1610512  1232844  1181949  1518933  1841266  1976976
# 38     P   Pennsylvania  1320191  1446723  1218591  1122030  1971479  1563062
# 50     W        Wyoming  1775190  1498098  1198212  1881688  1750527  1523124
#
#       Y2008    Y2009    Y2010    Y2011    Y2012    Y2013    Y2014    Y2015
# 21  1978904  1567651  1761048  1658538  1482203  1731917  1669749  1963337
# 16  1949478  1561528  1550433  1465812  1882929  1410249  1930090  1385528
# 6   1764457  1972730  1968730  1945524  1228529  1582249  1503156  1718072
# 38  1274168  1571032  1433835  1483292  1290329  1475344  1931500  1668232
# 50  1587602  1504455  1282142  1881814  1673668  1994022  1204029  1853858

# %%
income.sample(frac = 0.1)
# Out:
#    Index         State    Y2002    Y2003    Y2004    Y2005    Y2006    Y2007  \
# 31     N    New Mexico  1819239  1226057  1935991  1124400  1723493  1475985
# 4      C    California  1685349  1675807  1889570  1480280  1735069  1812546
# 44     U          Utah  1771096  1195861  1979395  1241662  1437456  1859416
# 27     N      Nebraska  1885081  1309769  1425527  1240465  1500594  1278272
# 41     S  South Dakota  1159037  1150689  1660148  1417141  1418586  1279134
#
#       Y2008    Y2009    Y2010    Y2011    Y2012    Y2013    Y2014    Y2015
# 31  1237704  1820856  1801430  1653384  1475715  1623388  1533494  1868612
# 4   1487315  1663809  1624509  1639670  1921845  1156536  1388461  1644607
# 44  1939284  1915865  1619186  1288285  1108281  1123353  1801019  1729273
# 27  1140598  1270585  1128711  1187207  1569665  1690920  1459243  1802211
# 41  1171870  1852424  1554782  1647245  1811156  1147488  1302834  1136443

# %%
income[['Index', 'State']]
# Out:
#    Index                 State
# 0      A               Alabama
# 1      A                Alaska
# 2      A               Arizona
# 3      A              Arkansas
# 4      C            California
# 5      C              Colorado
# 6      C           Connecticut
# 7      D              Delaware
# 8      D  District of Columbia
# 9      F               Florida
# 10     G               Georgia
# 11     H                Hawaii
# 12     I                 Idaho
# 13     I              Illinois
# 14     I               Indiana
# 15     I                  Iowa
# 16     K                Kansas
# 17     K              Kentucky
# 18     L             Louisiana
# 19     M                 Maine
# 20     M              Maryland
# 21     M         Massachusetts
# 22     M              Michigan
# 23     M             Minnesota
# 24     M           Mississippi
# 25     M              Missouri
# 26     M               Montana
# 27     N              Nebraska
# 28     N                Nevada
# ...

# %%
income.State
# Out:
# 0                  Alabama
# 1                   Alaska
# 2                  Arizona
# 3                 Arkansas
# 4               California
# 5                 Colorado
# 6              Connecticut
# 7                 Delaware
# 8     District of Columbia
# 9                  Florida
# 10                 Georgia
# 11                  Hawaii
# 12                   Idaho
# 13                Illinois
# 14                 Indiana
# 15                    Iowa
# 16                  Kansas
# 17                Kentucky
# 18               Louisiana
# 19                   Maine
# 20                Maryland
# 21           Massachusetts
# 22                Michigan
# 23               Minnesota
# 24             Mississippi
# 25                Missouri
# 26                 Montana
# 27                Nebraska
# 28                  Nevada
# 29           New Hampshire
# 30              New Jersey
# 31              New Mexico
# 32                New York
# 33          North Carolina
# ...

# %%
income.loc[0:2,['Index']]
# Out:
#   Index
# 0     A
# 1     A
# 2     A

# %%
income.loc[:,["Index","State","Y2008"]]
# Out:
#    Index                 State    Y2008
# 0      A               Alabama  1945229
# 1      A                Alaska  1551826
# 2      A               Arizona  1752886
# 3      A              Arkansas  1188104
# 4      C            California  1487315
# 5      C              Colorado  1875146
# 6      C           Connecticut  1764457
# 7      D              Delaware  1762096
# 8      D  District of Columbia  1193245
# 9      F               Florida  1756185
# 10     G               Georgia  1773090
# 11     H                Hawaii  1919423
# 12     I                 Idaho  1335481
# 13     I              Illinois  1871645
# 14     I               Indiana  1139551
# 15     I                  Iowa  1317983
# 16     K                Kansas  1949478
# 17     K              Kentucky  1301848
# 18     L             Louisiana  1185085
# 19     M                 Maine  1295877
# 20     M              Maryland  1112765
# 21     M         Massachusetts  1978904
# ...

# %%
income.loc[:,"Index":"Y2008"]
# Out:
#    Index                 State    Y2002    Y2003    Y2004    Y2005    Y2006  \
# 0      A               Alabama  1296530  1317711  1118631  1492583  1107408
# 1      A                Alaska  1170302  1960378  1818085  1447852  1861639
# 2      A               Arizona  1742027  1968140  1377583  1782199  1102568
# 3      A              Arkansas  1485531  1994927  1119299  1947979  1669191
# 4      C            California  1685349  1675807  1889570  1480280  1735069
# 5      C              Colorado  1343824  1878473  1886149  1236697  1871471
# 6      C           Connecticut  1610512  1232844  1181949  1518933  1841266
# 7      D              Delaware  1330403  1268673  1706751  1403759  1441351
# 8      D  District of Columbia  1111437  1993741  1374643  1827949  1803852
# 9      F               Florida  1964626  1468852  1419738  1362787  1339608
# 10     G               Georgia  1929009  1541565  1810773  1779091  1326846
# ...

# %%
income.iloc[0:2, 1:4]
# Out:
#      State    Y2002    Y2003
# 0  Alabama  1296530  1317711
# 1   Alaska  1170302  1960378
