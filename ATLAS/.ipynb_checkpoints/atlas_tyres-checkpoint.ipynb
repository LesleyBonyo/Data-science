# %% [markdown]
# # ATLAS TYRES

# %% [markdown]
# The excel sheet to be explored and analysed is from Atlas Tyres. It captures sales of their different models of tyres from January to July 2019. Each work sheet contains sales data for each model.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#from matplotlib.dates import DateFormatter

# %matplotlib inline

# %%
atlas = pd.read_excel("SALES BREAKDOWN.xlsx", None) #read excel sheet but open no particular sheet
atlas.keys() #sheets on the excel file represent different models of tyres
# Out:
# odict_keys(['155R12C ATL', '175-70R13 ATL', '175-70R14 ATL', '175R13C ATL', '185-65R15 ATL', '185-70R13 ATL', '185-70R14 ATL', '185-70R14 LL LMA 3 INF', '185R14C ATL', '195-65R15 ATL', '195-70R14 ATL', '195R14C LMC 8 ATL', '195R14C LMC 8 INF', '195R15C GREENVAN ATL', '195R15C INF 200', '205-55R16 GREEN ATL', '205-60R16 GREEN ATL', '205-65R15 ATL', '205-70R15 R620 ATL', '205R16C ATL', '215-45R17 ATL', '215-60R16 GREEN ATL', '215-70R15C ATL', '215-70R16 ATL', '225-55R17 SPORT GREEN ATL', '225-65R17 ATL', '225-70R15C ATL', '235-35R19 SPORT GREEN ATL', '235-55R18 ATL', '235-60R18 ATL', '235-70R16 ATL', '245-45R20 SPORT GREEN ATL', '255-55R19 CROSSWIND ATL', '265-70R19.5 ATL 18PR', '385-65R22.5 ATL 18PR', '9.5R17.5 ATL'])

# %%
#atlas = atlas[0:37] #ewmove columns wiht NaN values
sheet1 = atlas['155R12C ATL'] #view the first sheet
sheet1.head()
# Out:
#         DATE        DETAILS    QTY
# 0 2019-01-01  OPENING STOCK  300.0
# 1 2019-01-12          SALES   -2.0
# 2 2019-01-30          SALES   -2.0
# 3 2019-02-05          SALES  -10.0
# 4 2019-02-15          SALES   -1.0

# %%
sheet1.shape
# Out:
# (49, 3)

# %%
sheet1.tail()
# Out:
#    DATE DETAILS    QTY
# 44  NaT     NaN    NaN
# 45  NaT     NaN    NaN
# 46  NaT     NaN    NaN
# 47  NaT     NaN    NaN
# 48  NaT   TOTAL  151.0

# %%
sheet1
# Out:
#          DATE        DETAILS    QTY
# 0  2019-01-01  OPENING STOCK  300.0
# 1  2019-01-12          SALES   -2.0
# 2  2019-01-30          SALES   -2.0
# 3  2019-02-05          SALES  -10.0
# 4  2019-02-15          SALES   -1.0
# 5  2019-02-15          SALES   -4.0
# 6  2019-02-27          SALES   -2.0
# 7  2019-02-28          SALES   -2.0
# 8  2019-03-08          SALES   -2.0
# 9  2019-03-13          SALES   -2.0
# 10 2019-03-14          SALES   -2.0
# 11 2019-03-20          SALES   -4.0
# 12 2019-03-29          SALES   -4.0
# 13 2019-04-06          SALES   -2.0
# 14 2019-04-09          SALES   -5.0
# 15 2019-04-16          SALES   -5.0
# 16 2019-04-16          SALES   -4.0
# 17 2019-04-23          SALES   -2.0
# 18 2019-05-06          SALES  -10.0
# 19 2019-05-06          SALES   -6.0
# 20 2019-05-06          SALES   -4.0
# 21 2019-05-16   SALES RETURN    2.0
# 22 2019-05-16          SALES   -4.0
# 23 2019-05-16          SALES   -5.0
# 24 2019-05-21          SALES   -2.0
# ...

# %%
#sheet1 = sheet1[1:37] #include second row to 36th row
sheet1.loc[48,['QTY']]
# Out:
# QTY    151
# Name: 48, dtype: object

# %%
date_sheet1 = sheet1.loc[:,['DATE']]

# %%
qty_sheet1 = sheet1.loc[:,['QTY']]

# %%
plt.style.use('ggplot')
plt.plot(date_sheet1, qty_sheet1, color = 'blue') # comparing sales for tyre 155R12C ATL from January to July 2019
plt.title('Comparing sales for Tyre 155R12C ATL from January to July 2019')
plt.xlabel('Date')
plt.ylabel('Quantity of Sales')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_converter.py:129: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)
# Text(0,0.5,'Quantity of Sales')

# %%
sheet2 = atlas['175-70R13 ATL']
sheet2
# Out:
#          DATE        DETAILS    QTY
# 0  2019-01-01  OPENING STOCK  290.0
# 1  2019-01-08          SALES   -2.0
# 2  2019-01-16          SALES   -4.0
# 3  2019-01-18          SALES   -2.0
# 4  2019-01-18          SALES   -2.0
# 5  2019-01-27          SALES   -2.0
# 6  2019-03-11          SALES   -2.0
# 7  2019-03-17          SALES  -10.0
# 8  2019-03-17          SALES  -10.0
# 9  2019-05-16          SALES   -4.0
# 10 2019-05-19          SALES   -2.0
# 11 2019-05-25          SALES   -4.0
# 12 2019-05-27          SALES   -2.0
# 13        NaT            NaN    NaN
# 14        NaT            NaN    NaN
# 15        NaT            NaN    NaN
# 16        NaT            NaN    NaN
# 17        NaT            NaN    NaN
# 18        NaT          TOTAL  244.0

# %%
sheet2 = sheet2[1:13] #include row two to twelve
sheet2
# Out:
#          DATE DETAILS   QTY
# 1  2019-01-08   SALES  -2.0
# 2  2019-01-16   SALES  -4.0
# 3  2019-01-18   SALES  -2.0
# 4  2019-01-18   SALES  -2.0
# 5  2019-01-27   SALES  -2.0
# 6  2019-03-11   SALES  -2.0
# 7  2019-03-17   SALES -10.0
# 8  2019-03-17   SALES -10.0
# 9  2019-05-16   SALES  -4.0
# 10 2019-05-19   SALES  -2.0
# 11 2019-05-25   SALES  -4.0
# 12 2019-05-27   SALES  -2.0

# %%
date_sheet2 = sheet2.loc[:,['DATE']]
qty_sheet2 = sheet2.loc[:,['QTY']]

# %%
plt.style.use('ggplot')
plt.plot(date_sheet2, qty_sheet2, color = 'blue') # comparing sales for tyre 175-70R13 ATL from January to June 2019
plt.title('Comparing sales for Tyre 175-70R13 ATL from January to June 2019')
plt.xlabel('Date')
plt.ylabel('Quantity of Sales')
# Out:
# Text(0,0.5,'Quantity of Sales')

# %%
atlas_test = pd.concat(pd.read_excel("SALES BREAKDOWN.xlsx", None), ignore_index=True)
atlas_test
# Out:
#            DATE        DETAILS    QTY
# 0    2019-01-01  OPENING STOCK  300.0
# 1    2019-01-12          SALES   -2.0
# 2    2019-01-30          SALES   -2.0
# 3    2019-02-05          SALES  -10.0
# 4    2019-02-15          SALES   -1.0
# 5    2019-02-15          SALES   -4.0
# 6    2019-02-27          SALES   -2.0
# 7    2019-02-28          SALES   -2.0
# 8    2019-03-08          SALES   -2.0
# 9    2019-03-13          SALES   -2.0
# 10   2019-03-14          SALES   -2.0
# 11   2019-03-20          SALES   -4.0
# 12   2019-03-29          SALES   -4.0
# 13   2019-04-06          SALES   -2.0
# 14   2019-04-09          SALES   -5.0
# 15   2019-04-16          SALES   -5.0
# 16   2019-04-16          SALES   -4.0
# 17   2019-04-23          SALES   -2.0
# 18   2019-05-06          SALES  -10.0
# 19   2019-05-06          SALES   -6.0
# 20   2019-05-06          SALES   -4.0
# 21   2019-05-16   SALES RETURN    2.0
# 22   2019-05-16          SALES   -4.0
# 23   2019-05-16          SALES   -5.0
# ...

# %% [markdown]
# Comparing Sales of different model of Tyres as at June 2019

# %%
atlas.keys()
# Out:
# odict_keys(['155R12C ATL', '175-70R13 ATL', '175-70R14 ATL', '175R13C ATL', '185-65R15 ATL', '185-70R13 ATL', '185-70R14 ATL', '185-70R14 LL LMA 3 INF', '185R14C ATL', '195-65R15 ATL', '195-70R14 ATL', '195R14C LMC 8 ATL', '195R14C LMC 8 INF', '195R15C GREENVAN ATL', '195R15C INF 200', '205-55R16 GREEN ATL', '205-60R16 GREEN ATL', '205-65R15 ATL', '205-70R15 R620 ATL', '205R16C ATL', '215-45R17 ATL', '215-60R16 GREEN ATL', '215-70R15C ATL', '215-70R16 ATL', '225-55R17 SPORT GREEN ATL', '225-65R17 ATL', '225-70R15C ATL', '235-35R19 SPORT GREEN ATL', '235-55R18 ATL', '235-60R18 ATL', '235-70R16 ATL', '245-45R20 SPORT GREEN ATL', '255-55R19 CROSSWIND ATL', '265-70R19.5 ATL 18PR', '385-65R22.5 ATL 18PR', '9.5R17.5 ATL'])

# %% [markdown]
# Sale for Tyre model '155R12C ATL' from Jan-June 2019

# %%
sheet1 = atlas['155R12C ATL']
opening_stock1 = sheet1.loc[0,['QTY']]
closing_stock1 = sheet1.loc[48,['QTY']]
sale1 = opening_stock1 - closing_stock1
print(sale1)
# Out:
# QTY    149
# dtype: object

# %%
sheet2 = atlas['175-70R13 ATL']
opening_stock2 = sheet2.loc[0,['QTY']]
closing_stock2 = sheet2.loc[18,['QTY']]
sale2 = opening_stock2 - closing_stock2
print(sale2)
sheet3 = atlas['175-70R14 ATL']
opening_stock3 = sheet3.loc[0,['QTY']]
closing_stock3 = sheet3.loc[31,['QTY']]
sale3 = opening_stock3 - closing_stock3
print(sale3)
sheet4 = atlas['175R13C ATL']
opening_stock4 = sheet4.loc[0,['QTY']]
closing_stock4 = sheet4.loc[22,['QTY']]
sale4 = opening_stock4 - closing_stock4
print(sale4)
sheet5 = atlas['185-65R15 ATL']
opening_stock5 = sheet5.loc[0,['QTY']]
closing_stock5 = sheet5.loc[15,['QTY']]
sale5 = opening_stock5 - closing_stock5
print(sale5)
sheet6 = atlas['185-70R13 ATL']
opening_stock6 = sheet6.loc[0,['QTY']]
closing_stock6 = sheet6.loc[118,['QTY']]
sale6 = opening_stock6 - closing_stock6
print(sale6)
sheet7 = atlas['185-70R14 ATL']
opening_stock7 = sheet7.loc[0,['QTY']]
closing_stock7 = sheet7.loc[100,['QTY']]
sale7 = opening_stock7 - closing_stock7
print(sale7)
sheet8 = atlas['185-70R14 LL LMA 3 INF']
opening_stock8 = sheet8.loc[0,['QTY']]
closing_stock8 = sheet8.loc[57,['QTY']]
sale8 = opening_stock8 - closing_stock8
print(sale8)
sheet9 = atlas['185R14C ATL']
opening_stock9 = sheet9.loc[0,['QTY']]
closing_stock9 = sheet9.loc[10,['QTY']]
sale9 = opening_stock9 - closing_stock9
print(sale9)
sheet10 = atlas['195-65R15 ATL']
opening_stock10 = sheet10.loc[0,['QTY']]
stock_added10 = sheet10.loc[55,['QTY']]
closing_stock10 = sheet10.loc[95,['QTY']]
sale10 = opening_stock10 + stock_added10 - closing_stock10
print(sale10)
sheet11 = atlas['195-70R14 ATL']
opening_stock11 = sheet11.loc[0,['QTY']]
closing_stock11 = sheet11.loc[8,['QTY']]
sale11 = opening_stock11 - closing_stock11
print(sale11)
sheet12 = atlas['195R14C LMC 8 ATL']
opening_stock12 = sheet12.loc[0,['QTY']]
stock_added12 = sheet12.loc[1,['QTY']]
closing_stock12 = sheet12.loc[21,['QTY']]
sale12 = opening_stock12 + stock_added12 - closing_stock12
print(sale12)
sheet13 = atlas['195R14C LMC 8 INF']
opening_stock13 = sheet13.loc[0,['QTY']]
closing_stock13 = sheet13.loc[16,['QTY']]
sale13 = opening_stock13 - closing_stock13
print(sale13)
sheet14 = atlas['195R15C GREENVAN ATL']
opening_stock14 = sheet14.loc[0,['QTY']]
stock_added14 = sheet14.loc[1,['QTY']]
closing_stock14 = sheet14.loc[15,['QTY']]
sale14 = opening_stock14 + stock_added14 - closing_stock14
print(sale14)
sheet15 = atlas['195R15C INF 200']
opening_stock15 = sheet15.loc[0,['QTY']]
closing_stock15 = sheet15.loc[14,['QTY']]
sale15 = opening_stock15 - closing_stock15
print(sale15)
sheet16 = atlas['205-55R16 GREEN ATL']
opening_stock16 = sheet16.loc[0,['QTY']]
closing_stock16 = sheet16.loc[7,['QTY']]
sale16 = opening_stock16 - closing_stock16
print(sale16)
sheet17 = atlas['205-60R16 GREEN ATL']
opening_stock17 = sheet17.loc[0,['QTY']]
closing_stock17 = sheet17.loc[10,['QTY']]
sale17 = opening_stock17 - closing_stock17
print(sale17)
sheet18 = atlas['205-65R15 ATL']
opening_stock18 = sheet18.loc[0,['QTY']]
closing_stock18 = sheet18.loc[69,['QTY']]
sale18 = opening_stock18 - closing_stock18
print(sale18)
sheet19 = atlas['205-70R15 R620 ATL']
opening_stock19 = sheet19.loc[0,['QTY']]
closing_stock19 = sheet19.loc[44,['QTY']]
sale19 = opening_stock19 - closing_stock19
print(sale19)
sheet20 = atlas['205R16C ATL']
opening_stock20 = sheet20.loc[0,['QTY']]
closing_stock20 = sheet20.loc[7,['QTY']]
sale20 = opening_stock20 - closing_stock20
print(sale20)
sheet21 = atlas['215-45R17 ATL']
opening_stock21 = sheet21.loc[0,['QTY']]
closing_stock21 = sheet21.loc[4,['QTY']]
sale21 = opening_stock21 - closing_stock21
print(sale21)
sheet22 = atlas['215-60R16 GREEN ATL']
opening_stock22 = sheet22.loc[0,['QTY']]
closing_stock22 = sheet22.loc[8,['QTY']]
sale22 = opening_stock22 - closing_stock22
print(sale22)
sheet23 = atlas['215-70R15C ATL']
opening_stock23 = sheet23.loc[0,['QTY']]
closing_stock23 = sheet23.loc[19,['QTY']]
sale23 = opening_stock23 - closing_stock23
print(sale23)
sheet24 = atlas['215-70R16 ATL']
opening_stock24 = sheet24.loc[0,['QTY']]
closing_stock24 = sheet24.loc[45,['QTY']]
sale24 = opening_stock24 - closing_stock24
print(sale24)
sheet25 = atlas['225-55R17 SPORT GREEN ATL']
opening_stock25 = sheet25.loc[0,['QTY']]
closing_stock25 = sheet25.loc[3,['QTY']]
sale25 = opening_stock25 - closing_stock25
print(sale25)
sheet26 = atlas['225-65R17 ATL']
opening_stock26 = sheet26.loc[0,['QTY']]
stock_added26 = sheet26.loc[12,['QTY']]
closing_stock26 = sheet26.loc[16,['QTY']]
sale26 = opening_stock26 + stock_added26 - closing_stock26
print(sale26)
sheet27 = atlas['225-70R15C ATL']
opening_stock27 = sheet27.loc[0,['QTY']]
closing_stock27 = sheet27.loc[20,['QTY']]
sale27 = opening_stock27 - closing_stock27
print(sale27)
sheet28 = atlas['235-35R19 SPORT GREEN ATL']
opening_stock28 = sheet28.loc[0,['QTY']]
closing_stock28 = sheet28.loc[3,['QTY']]
sale28 = opening_stock28 - closing_stock28
print(sale28)
sheet29 = atlas['235-55R18 ATL']
opening_stock29 = sheet29.loc[0,['QTY']]
closing_stock29 = sheet29.loc[18,['QTY']]
sale29 = opening_stock29 - closing_stock29
print(sale29)
sheet30 = atlas['235-60R18 ATL']
opening_stock30 = sheet30.loc[0,['QTY']]
closing_stock30 = sheet30.loc[13,['QTY']]
sale30 = opening_stock30 - closing_stock30
print(sale30)
sheet31 = atlas['235-70R16 ATL']
opening_stock31 = sheet31.loc[0,['QTY']]
closing_stock31 = sheet31.loc[9,['QTY']]
sale31 = opening_stock31 - closing_stock31
print(sale31)
sheet32 = atlas['245-45R20 SPORT GREEN ATL']
opening_stock32 = sheet32.loc[0,['QTY']]
closing_stock32 = sheet32.loc[3,['QTY']]
sale32 = opening_stock32 - closing_stock32
print(sale32)
sheet33 = atlas['255-55R19 CROSSWIND ATL']
opening_stock33 = sheet33.loc[0,['QTY']]
closing_stock33 = sheet33.loc[5,['QTY']]
sale33 = opening_stock33 - closing_stock33
print(sale33)
sheet34 = atlas['265-70R19.5 ATL 18PR']
opening_stock34 = sheet34.loc[0,['QTY']]
closing_stock34 = sheet34.loc[37,['QTY']]
sale34 = opening_stock34 - closing_stock34
print(sale34)
sheet35 = atlas['385-65R22.5 ATL 18PR']
opening_stock35 = sheet35.loc[0,['QTY']]
closing_stock35 = sheet35.loc[6,['QTY']]
sale35 = opening_stock35 - closing_stock35
print(sale35)
sheet36 = atlas['9.5R17.5 ATL']
opening_stock36 = sheet36.loc[0,['QTY']]
closing_stock36 = sheet36.loc[40,['QTY']]
sale36 = opening_stock36 - closing_stock36
print(sale36)
# Out:
# QTY    46
# dtype: object
# QTY    66
# dtype: object
# QTY    99
# dtype: object
# QTY    33
# dtype: object
# QTY    945
# dtype: object
# QTY    908
# dtype: object
# QTY    449
# dtype: object
# QTY    23
# dtype: object
# QTY    740
# dtype: object
# QTY    18
# dtype: object
# QTY    75
# dtype: object
# QTY    64
# dtype: object
# QTY    31
# dtype: object
# QTY    56
# dtype: object
# QTY    8
# dtype: object
# QTY    18
# dtype: object
# QTY    266
# dtype: object
# QTY    190
# dtype: object
# QTY    12
# dtype: object
# QTY    8
# dtype: object
# QTY    9
# dtype: object
# QTY    46
# dtype: object
# QTY    122
# dtype: object
# QTY    0
# dtype: object
# QTY    32
# dtype: object
# QTY    41
# dtype: object
# QTY    0
# dtype: object
# QTY    36
# dtype: object
# QTY    22
# dtype: object
# QTY    21
# dtype: object
# QTY    0
# dtype: object
# QTY    0
# dtype: object
# QTY    83
# dtype: object
# QTY    8
# dtype: object
# QTY    78
# dtype: object

# %%
tyre_model = ['155R12C ATL', '175-70R13 ATL', '175-70R14 ATL', '175R13C ATL', '185-65R15 ATL', '185-70R13 ATL', '185-70R14 ATL', '185-70R14 LL LMA 3 INF', '185R14C ATL', '195-65R15 ATL', '195-70R14 ATL', '195R14C LMC 8 ATL', '195R14C LMC 8 INF', '195R15C GREENVAN ATL', '195R15C INF 200', '205-55R16 GREEN ATL', '205-60R16 GREEN ATL', '205-65R15 ATL', '205-70R15 R620 ATL', '205R16C ATL', '215-45R17 ATL', '215-60R16 GREEN ATL', '215-70R15C ATL', '215-70R16 ATL', '225-55R17 SPORT GREEN ATL', '225-65R17 ATL', '225-70R15C ATL', '235-35R19 SPORT GREEN ATL', '235-55R18 ATL', '235-60R18 ATL', '235-70R16 ATL', '245-45R20 SPORT GREEN ATL', '255-55R19 CROSSWIND ATL', '265-70R19.5 ATL 18PR', '385-65R22.5 ATL 18PR', '9.5R17.5 ATL']

# %%
sales = [sale1, sale2,sale3, sale4, sale5, sale6, sale7, sale8, sale9, sale10, sale11, sale12, sale13, sale14, sale15, sale16, sale17, sale18, sale19, sale20, sale21, sale22, sale23, sale24, sale25, sale26, sale27, sale28, sale29, sale30, sale31, sale32, sale33, sale34, sale35, sale36]

# %%
#plt.style.use('ggplot')
plt.plot(tyre_model, sales, color = 'blue') 
plt.title('Comparing sales for Different model of tyres from January to June 2019')
plt.xlabel('Tyre Model')
plt.ylabel('Quantity of Sales')
# Out:
# Text(0,0.5,'Quantity of Sales')
